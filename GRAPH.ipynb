# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
Joeyfood = pd.read_csv('/content/MYFOOD.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-963d627e2ff0> in <cell line: 1>()
# ----> 1 Joeyfood = pd.read_csv('/content/MYFOOD.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
Joeyfood

# %%
x = Joeyfood['cost_of_the_order']
y = Joeyfood['cuisine_type']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-258045c4ed3f> in <cell line: 1>()
# ----> 1 x = Joeyfood['cost_of_the_order']
#       2 y = Joeyfood['cuisine_type']
#
# NameError: name 'Joeyfood' is not defined

# %%
plt.xlabel('cost_of_the_order', fontsize = 20)
plt.ylabel('cuisine_type', fontsize = 20)
plt.bar(x, y)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.pie(Joeyfood['cost_of_the_order'],labels = Joeyfood['cuisine_type'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x79641b94aec0>,
# ...
#  [Text(0.7974532827403125, 0.7576729253752569, 'Korean'),
#   Text(-0.26931278396813435, 1.0665226787984086, 'Japanese'),
#   Text(-0.8249818830158607, 0.7276021527563019, 'Mexican'),
#   Text(-1.050556232279807, -0.326085269244191, 'American'),
#   Text(-0.2848323690067009, -1.062483186486276, 'American'),
#   Text(0.6636377221779053, -0.8772599236842645, 'Indian'),
#   Text(1.0876501247035213, -0.16436911581077038, 'Italian')],
#  [Text(0.4349745178583522, 0.4132761411137764, '24.2%'),
#   Text(-0.1468978821644369, 0.58173964298095, '9.5%'),
#   Text(-0.44999011800865124, 0.3968739015034374, '9.6%'),
#   Text(-0.5730306721526219, -0.17786469231501326, '23.0%'),
#   Text(-0.15536311036729136, -0.5795362835379686, '9.1%'),
#   Text(0.3619842120970392, -0.4785054129186897, '19.8%'),
#   Text(0.5932637043837389, -0.08965588135132928, '4.8%')])
